# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
taxi_df = sns.load_dataset("taxis")

# %%
taxi_df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
taxi_df["pickup_borough"].value_counts()
# Out:
# Manhattan    5268
# Queens        657
# Brooklyn      383
# Bronx          99
# Name: pickup_borough, dtype: int64

# %%
taxi_df["dropoff_borough"].value_counts()
# Out:
# Manhattan        5206
# Queens            542
# Brooklyn          501
# Bronx             137
# Staten Island       2
# Name: dropoff_borough, dtype: int64

# %%
taxi_df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
import pandas as pd

taxi_df['pickup'] = pd.to_datetime(taxi_df['pickup'])
taxi_df['dropoff'] = pd.to_datetime(taxi_df['dropoff'])

taxi_df['duration'] = taxi_df['dropoff'] - taxi_df['pickup']

taxi_df['total_duration'] = taxi_df['duration'].dt.total_seconds()

taxi_df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
payment_mapping = {
    'cash': 0,
    'credit card': 1,
   
}
taxi_df['payment_encoded'] = taxi_df['payment'].map(payment_mapping)


color_mapping = {
    'yellow': 0,
    'green': 1,
 
}
taxi_df['color_encoded'] = taxi_df['color'].map(color_mapping)



taxi_df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df = taxi_df

# %%
df.drop(['payment', 'color', 'pickup_zone', 'dropoff_zone', 'pickup_borough','dropoff_borough', 'pickup', 'dropoff'], axis=1, inplace=True)

# %%
df.drop(['tip', 'total'], axis=1)
# Out:
#       passengers  distance  fare  tolls        duration  total_duration  \
# 0              1      1.60   7.0    0.0 0 days 00:06:15           375.0
# 1              1      0.79   5.0    0.0 0 days 00:07:05           425.0
# 2              1      1.37   7.5    0.0 0 days 00:07:24           444.0
# 3              1      7.70  27.0    0.0 0 days 00:25:52          1552.0
# 4              3      2.16   9.0    0.0 0 days 00:09:32           572.0
# ...          ...       ...   ...    ...             ...             ...
# 6428           1      0.75   4.5    0.0 0 days 00:03:34           214.0
# 6429           1     18.74  58.0    0.0 0 days 00:56:23          3383.0
# 6430           1      4.14  16.0    0.0 0 days 00:19:07          1147.0
# 6431           1      1.12   6.0    0.0 0 days 00:05:04           304.0
# 6432           1      3.85  15.0    0.0 0 days 00:16:40          1000.0
#
#       payment_encoded  color_encoded
# 0                 1.0              0
# ...

# %%
#features = df.drop(['fare'], axis=1)
features = df['total_duration']
labels = df['fare']

# %%
from sklearn.model_selection import train_test_split
from qiskit.utils import algorithm_globals

algorithm_globals.random_seed = 123
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, train_size=0.8, random_state=algorithm_globals.random_seed)

# %%
import numpy as np

def data_map_eq12(x: np.ndarray) -> float:
    coeff = x[0] if len(x) == 1 else reduce(lambda m, n: np.pi*(m * n), np.cos(x))
    return coeff

from qiskit.circuit.library import PauliFeatureMap
from functools import reduce

num_features = 1

feature_map = PauliFeatureMap(feature_dimension=num_features, 
                              paulis = ['ZI','IZ','ZZ'],
                              reps=1, 
                              entanglement='full', 
                              data_map_func=data_map_eq12)
feature_map.decompose().draw(output="mpl", fold=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 17
#      10 num_features = 1
#      12 feature_map = PauliFeatureMap(feature_dimension=num_features,
#      13                               paulis = ['ZI','IZ','ZZ'],
#      14                               reps=1,
#      15                               entanglement='full',
#      16                               data_map_func=data_map_eq12)
# ---> 17 feature_map.decompose().draw(output="mpl", fold=20)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\qiskit\circuit\library\blueprintcircuit.py:97, in BlueprintCircuit.decompose(self, gates_to_decompose, reps)
#      95 def decompose(self, gates_to_decompose=None, reps=1):
#      96     if not self._is_built:
# ---> 97         self._build()
#      98     return super().decompose(gates_to_decompose, reps)
#
# ...

# %%
from qiskit.primitives import Sampler

sampler = Sampler()

# %%
from qiskit import Aer
from qiskit.algorithms.state_fidelities import ComputeUncompute
from qiskit_machine_learning.kernels import FidelityQuantumKernel

import time
from qiskit_machine_learning.algorithms import QSVR, VQR

fidelity = ComputeUncompute(sampler=sampler)
kernel = FidelityQuantumKernel(fidelity=fidelity, feature_map=feature_map)

# %%
print(QSVR)
# Out:
# <class 'qiskit_machine_learning.algorithms.regressors.qsvr.QSVR'>

# %%
def callback_graph(weights, obj_func_eval):
    clear_output(wait=True)
    objective_func_vals.append(obj_func_eval)
    plt.title("Objective function value against iteration")
    plt.xlabel("Iteration")
    plt.ylabel("Objective function value")
    plt.plot(range(len(objective_func_vals)), objective_func_vals)
    plt.show()

# %%
from qiskit.circuit.library import ZZFeatureMap
from qiskit.algorithms.optimizers import COBYLA, L_BFGS_B
from qiskit.circuit.library import RealAmplitudes

ansatz = RealAmplitudes(num_qubits=num_features, reps=3)
ansatz.decompose().draw(output="mpl", fold=20)

#vqr = VQR(
#    feature_map=feature_map,
#    ansatz=ansatz,
#    optimizer=L_BFGS_B(maxiter=100),
#    callback=callback_graph,
#)

# %%
vqr = VQR(
    feature_map=feature_map,
    ansatz=ansatz,
    optimizer=L_BFGS_B(maxiter=100),
    callback=callback_graph,
)

# %%
import matplotlib.pyplot as plt

# create empty array for callback to store evaluations of the objective function
objective_func_vals = []
#plt.rcParams["figure.figsize"] = (12, 6)
print(train_features, train_labels)
# fit regressor
vqr.fit(train_features, train_labels)

# return to default figsize
#plt.rcParams["figure.figsize"] = (6, 4)

# score result
score = vqr.score(train_features, train_labels)
print(score)
# Out:
#       passengers  distance   tip  tolls  total        duration  \
# 333            1      2.14  0.00    0.0  11.80 0 days 00:05:35
# 563            1      1.42  2.06    0.0  12.36 0 days 00:05:11
# 2774           1      0.95  1.00    0.0  10.80 0 days 00:06:46
# 388            1      3.37  2.00    0.0  19.30 0 days 00:15:26
# 3932           2     15.05  0.00    0.0  44.30 0 days 00:34:53
# ...          ...       ...   ...    ...    ...             ...
# 5218           1      0.90  2.16    0.0  12.96 0 days 00:10:07
# 4060           3      0.41  2.64    0.0  11.44 0 days 00:04:25
# 1346           1      5.77  2.00    0.0  34.80 0 days 00:43:43
# 3454           0      5.80  4.75    0.0  28.55 0 days 00:20:58
# 3582           4      0.70  2.15    0.0  12.95 0 days 00:09:07
#
#       total_duration  payment_encoded  color_encoded
# 333            335.0              0.0              0
# 563            311.0              1.0              0
# ...

# %%
X = features
y = labels


X = X.to_numpy()
X = pd.DataFrame(X)
y = y.to_numpy()
y = y.flatten()

print(X)
print(y)
plt.plot(X_, f(X_), "r--")
plt.plot(X, y, "bo")
plt.show()
# Out:
#            0
# 0      375.0
# 1      425.0
# 2      444.0
# 3     1552.0
# 4      572.0
# ...      ...
# 6428   214.0
# 6429  3383.0
# 6430  1147.0
# 6431   304.0
# 6432  1000.0
#
# [6433 rows x 1 columns]
# [ 7.   5.   7.5 ... 16.   6.  15. ]

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output
from qiskit import QuantumCircuit
from qiskit.algorithms.optimizers import COBYLA, L_BFGS_B
from qiskit.circuit import Parameter
from qiskit.circuit.library import RealAmplitudes, ZZFeatureMap
from qiskit.utils import algorithm_globals


from qiskit_machine_learning.algorithms.classifiers import NeuralNetworkClassifier, VQC
from qiskit_machine_learning.algorithms.regressors import NeuralNetworkRegressor, VQR
from qiskit_machine_learning.neural_networks import SamplerQNN, EstimatorQNN



# construct simple feature map
param_x = Parameter("x")
feature_map = QuantumCircuit(1, name="fm")
feature_map.ry(param_x, 0)

# construct simple ansatz
param_y = Parameter("y")
ansatz = QuantumCircuit(1, name="vf")
ansatz.ry(param_y, 0)

# construct a circuit
qc = QuantumCircuit(1)
qc.compose(feature_map, inplace=True)
qc.compose(ansatz, inplace=True)

# construct QNN
regression_estimator_qnn = EstimatorQNN(
    circuit=qc, input_params=feature_map.parameters, weight_params=ansatz.parameters
)

# %%
# construct the regressor from the neural network
regressor = NeuralNetworkRegressor(
    neural_network=regression_estimator_qnn,
    loss="squared_error",
    optimizer=L_BFGS_B(maxiter=10),
    callback=callback_graph,
)

# %%
# create empty array for callback to store evaluations of the objective function
objective_func_vals = []
plt.rcParams["figure.figsize"] = (12, 6)

# fit to data
regressor.fit(X, y)

# return to default figsize
plt.rcParams["figure.figsize"] = (6, 4)

# score the result
regressor.score(X, y)
# Out:
# -1.2843319563824211

# %%
# plot target function
plt.plot(X_, f(X_), "r--")

# plot data
plt.plot(X, y, "bo")

# plot fitted line
y_ = regressor.predict(X_)
plt.plot(X_, y_, "g-")
plt.show()

# %%
vqr = VQR(
    feature_map=feature_map,
    ansatz=ansatz,
    optimizer=L_BFGS_B(maxiter=100),
    callback=callback_graph,
)

# %%
# create empty array for callback to store evaluations of the objective function
objective_func_vals = []
plt.rcParams["figure.figsize"] = (12, 6)

# fit regressor
vqr.fit(X, y)

# return to default figsize
plt.rcParams["figure.figsize"] = (6, 4)

# score result
vqr.score(X, y)
# Out:
# -1.2843319563824211

# %%
# plot target function
plt.plot(X_, f(X_), "r--")

# plot data
plt.plot(X, y, "bo")

# plot fitted line
y_ = vqr.predict(X_)
plt.plot(X_, y_, "g-")
plt.show()
